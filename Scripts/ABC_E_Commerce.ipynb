# %% [markdown]
# Working on CUSTOMERS table. changing the customer_id into readable format.as map

# %%
from numpy._core.defchararray import zfill
import pandas as pd

df = pd.read_csv("CUSTOMERS.csv")

distinct_ids = df['customer_id'].unique()

mapping = pd.DataFrame({
    "customer_id" : distinct_ids,
    "new_customer_id" : [f"CUST{str(i).zfill(5)}" for i in range(1,len(distinct_ids)+1)]
})

mapping.to_csv("customer_id_map.csv", index=False)

# %% [markdown]
# Working on CUSTOMERS table. customer_unique_id changes into names.

# %%
import pandas as pd
import random
import re

df = pd.read_csv("CUSTOMERS.csv")

first_names = [
"Aarav","Aarohi","Aarya","Aayansh","Abel","Abha","Abhi","Abigail","Abin","Abir","Abraham","Abrar","Aby","Ada","Adah","Adalyn","Adam","Adarsh","Addison","Adele","Adeline","Aditi","Aditya","Adley","Adriana","Adrian","Advait","Agnes","Ahaan","Ahlam",
"Aiden","Aileen","Aimee","Ainsley","Aisha","Aishani","Aishwarya","Akansha","Akhil","Akira","Alaia","Alan","Albert","Aleena","Alejandra","Alejandro","Alek","Alessia","Alex","Alexa","Alexander","Alexandra","Alexis","Alfie","Alia","Alice","Alicia",
"Alina","Aline","Alisha","Alison","Allegra","Allan","Allen","Allison","Alma","Alok","Alondra","Alyssa","Amaira","Amal","Amanda","Amani","Amar","Amara","Amari","Amber","Amelia","Amey","Amir","Amira","Amisha","Amit","Amitabh","Amiyah","Amna","Amogh",
"Amy","Ana","Anagha","Ananya","Anaya","Anderson","Andre","Andrea","Andrei","Andres","Andrew","Angel","Angela","Angelina","Angelo","Anika","Anil","Anirudh","Anisha","Anita","Aniya","Anjali","Ankita","Ankur","Anna","Annabelle","Anne","Annie","Ansh",
"Anshika","Anshul","Antara","Anthony","Antonio","Anu","Anuja","Anusha","Anvi","Anya","Aparna","April","Aradhya","Arav","Aravind","Archana","Archer","Arden","Arham","Aria","Ariana","Ariel","Arif","Arjun","Arlo","Arman","Arnav","Arno","Arnold",
"Aron","Arpita","Arsh","Arshia","Arun","Arya","Aryan","Asa","Ash","Asha","Ashanti","Ashish","Ashlyn","Ashton","Asif","Asma","Aspen","Aster","Atharv","Aubree","Aubrey","Audrey","August","Aurelia","Ava","Avery","Avik","Avinash","Avi","Avni","Ayaan",
"Ayanna","Aydin","Ayesha","Ayra","Ayush","Azaria","Aziz","Azra",
"Bailey","Barbara","Barnet","Barry","Bashir","Beau","Becca","Becky","Bella","Ben","Benjamin","Benny","Benson","Beth","Bethany","Bianca","Bill","Billy","Blair","Blake","Blessy","Bob","Bobby","Braden","Bradley","Brady","Brandon","Brayden","Brea","Brenda",
"Brett","Briana","Brianna","Bridgit","Brin","Brielle","Brianna","Brock","Brody","Brook","Brooke","Bruce","Bruno","Bryan","Bryce","Bryson",
"Zach","Zachary","Zada","Zaid","Zain","Zaira","Zander","Zara","Zaria","Zayan","Zayden","Zelda","Zenia","Zia","Zidan","Zoe","Zoey","Zola","Zora"
]

# Optional: reproducible randomness
random.seed(42)

base = (
    df[['customer_unique_id', 'customer_city']]
    .drop_duplicates(subset='customer_unique_id', keep='first')
    .reset_index(drop=True)
)

def generate_name(row):
    first = random.choice(first_names)
    last = row['customer_city']
    return f"{first} {last}".strip()

base['customer_name'] = base.apply(generate_name, axis=1)

customer_name_table = base[['customer_unique_id', 'customer_name']]

customer_name_table.to_csv("customer_name_table.csv", index=False)

# %% [markdown]
# Working on ORDERS table . order_id is changing into readable names.

# %%
from numpy._core.defchararray import zfill
import pandas as pd

df = pd.read_csv("ORDERS.csv")

distinct_ids = df['order_id'].unique()

mapping = pd.DataFrame({
    "order_id" : distinct_ids,
    "new_order_id" : [f"ORDR{str(i).zfill(5)}" for i in range(1,len(distinct_ids)+1)]
})

mapping.to_csv("order_id_map.csv", index=False)

# %% [markdown]
# Working on  PRODUCTS table. product_id need to change into readable id's

# %%
from numpy._core.defchararray import zfill
import pandas as pd

df = pd.read_csv("PRODUCTS.csv")

distinct_ids = df['product_id'].unique()

mapping = pd.DataFrame({
    "product_id" : distinct_ids,
    "new_product_id" : [f"PRD{str(i).zfill(5)}" for i in range(1,len(distinct_ids)+1)]
})

mapping.to_csv("product_id_map.csv", index=False)

# %% [markdown]
# Working on SELLERS table. seller_id need to change into readable id

# %%
from numpy._core.defchararray import zfill
import pandas as pd

df = pd.read_csv("SELLERS.csv")

distinct_ids = df['seller_id'].unique()

mapping = pd.DataFrame({
    "seller_id" : distinct_ids,
    "new_seller_id" : [f"SLR{str(i).zfill(5)}" for i in range(1,len(distinct_ids)+1)]
})

mapping.to_csv("seller_id_map.csv", index=False)

# %% [markdown]
# MAKING CUSTOMERS table. rechanges the whole table data.

# %%
import pandas as pd

customers = pd.read_csv("CUSTOMERS.csv")
mapping = pd.read_csv("/content/Mapped ids/customer_id_map.csv")

id_map = dict(zip(mapping['customer_id'], mapping['new_customer_id']))

customers['customer_id'] = customers['customer_id'].map(id_map).fillna(customers['customer_id'])

customers.to_csv("/content/New Dataset/CUSTOMERS_UPDATED.csv", index=False)

# %% [markdown]
# MAKING ORDERS table. order_id and customer_id.

# %%
import pandas as pd

orders = pd.read_csv("ORDERS.csv")
mapping_customer_id = pd.read_csv("/content/Mapped ids/customer_id_map.csv")
mapping_order_id = pd.read_csv("/content/Mapped ids/order_id_map.csv")

cust_id_map = dict(zip(mapping_customer_id['customer_id'], mapping_customer_id['new_customer_id']))
ord_id_map = dict(zip(mapping_order_id['order_id'], mapping_order_id['new_order_id']))


orders['customer_id'] = orders['customer_id'].map(cust_id_map).fillna(orders['customer_id'])
orders['order_id'] = orders['order_id'].map(ord_id_map).fillna(orders['order_id'])

orders.to_csv("/content/New Dataset/ORDERS_UPDATED.csv", index=False)

# %% [markdown]
# Making PRODUCTS_WITH_NAMES table. rechanging the product_ID

# %%
import pandas as pd

products = pd.read_csv("PRODUCTS_WITH_NAMES.csv")
mapping = pd.read_csv("/content/Mapped ids/product_id_map.csv")

id_map = dict(zip(mapping['product_id'], mapping['new_product_id']))

products['product_id'] = products['product_id'].map(id_map).fillna(products['product_id'])

products.to_csv("/content/New Dataset/PRODUCTS_UPDATED.csv", index=False)

# %% [markdown]
# Making SELLERS table. rechanging the seller_id

# %%
import pandas as pd

sellers = pd.read_csv("SELLERS.csv")
mapping = pd.read_csv("/content/Mapped ids/seller_id_map.csv")

id_map = dict(zip(mapping['seller_id'], mapping['new_seller_id']))

sellers['seller_id'] = sellers['seller_id'].map(id_map).fillna(sellers['seller_id'])

sellers.to_csv("/content/New Dataset/SELLERS_UPDATED.csv", index=False)

# %% [markdown]
# MAKING ORDER_REVIEW_RATINGS table.  order_id rechanges.

# %%
import pandas as pd

order_rev_rat = pd.read_csv("ORDER_REVIEW_RATINGS.csv")
mapping = pd.read_csv("/content/Mapped ids/order_id_map.csv")

id_map = dict(zip(mapping['order_id'], mapping['new_order_id']))

order_rev_rat['order_id'] = order_rev_rat['order_id'].map(id_map).fillna(order_rev_rat['order_id'])

order_rev_rat.to_csv("/content/New Dataset/ORDER_REVIEW_RATINGS_UPDATED.csv", index=False)

# %% [markdown]
# Making ORDER_PAYMENTS table. order_id rechanges.

# %%
import pandas as pd

order_payments = pd.read_csv("ORDER_PAYMENTS.csv")
mapping = pd.read_csv("/content/Mapped ids/order_id_map.csv")

id_map = dict(zip(mapping['order_id'], mapping['new_order_id']))

order_payments['order_id'] = order_payments['order_id'].map(id_map).fillna(order_payments['order_id'])

order_payments.to_csv("/content/New Dataset/ORDER_PAYMENTS_UPDATED.csv", index=False)

# %% [markdown]
# Making ORDER_ITEMS table. changes order_id, product_id, seller_id .

# %%
import pandas as pd

order_items = pd.read_csv("ORDER_ITEMS.csv")

mapping_product_id = pd.read_csv("/content/Mapped ids/product_id_map.csv")
mapping_order_id = pd.read_csv("/content/Mapped ids/order_id_map.csv")
mapping_seller_id = pd.read_csv("/content/Mapped ids/seller_id_map.csv")

prod_id_map = dict(zip(mapping_product_id['product_id'], mapping_product_id['new_product_id']))
ord_id_map = dict(zip(mapping_order_id['order_id'], mapping_order_id['new_order_id']))
selr_id_map = dict(zip(mapping_seller_id['seller_id'], mapping_seller_id['new_seller_id']))

order_items['product_id'] = order_items['product_id'].map(prod_id_map).fillna(order_items['product_id'])
order_items['order_id'] = order_items['order_id'].map(ord_id_map).fillna(order_items['order_id'])
order_items['seller_id'] = order_items['seller_id'].map(selr_id_map).fillna(order_items['seller_id'])

order_items.to_csv("/content/New Dataset/ORDER_ITEMS_UPDATED.csv", index=False)
